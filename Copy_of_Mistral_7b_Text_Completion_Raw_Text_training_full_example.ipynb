# %% [markdown]
# <a href="https://colab.research.google.com/github/MarjovanLier/ConventionalCommitAgent/blob/main/Copy_of_Mistral_7b_Text_Completion_Raw_Text_training_full_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Text Completion / Raw Text Training
# This is a community notebook collaboration with [Mithex].
#
# We train on `Tiny Stories` (link [here](https://huggingface.co/datasets/roneneldan/TinyStories)) which is a collection of small stories. For example:
# ```
# Once upon a time, there was a little car named Beep. Beep loved to go fast and play in the sun.
# Beep was a healthy car because he always had good fuel....
# ```
# Instead of `Alpaca`'s Question Answer format, one only needs 1 column - the `"text"` column. This means you can finetune on any dataset and let your model act as a text completion model, like for novel writing.
#
# ---
#
# To run this, press "Runtime" and press "Run all" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers "trl<0.9.0" peft accelerate bitsandbytes

# %% [markdown]
# * We support Llama, Mistral, CodeLlama, TinyLlama, Vicuna, Open Hermes etc
# * And Yi, Qwen, Deepseek, all Llama, Mistral derived archs.
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] We make Llama-3 15 trillion tokens **2x faster**! See our [Llama-3 notebook](https://colab.research.google.com/drive/135ced7oHytdxu3N2DNe1Z0kqjyYIkDXp?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-v0.3-bnb-4bit",      # New Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/llama-3-8b-bnb-4bit",           # Llama-3 15 trillion tokens model 2x faster!
    "unsloth/llama-3-8b-Instruct-bnb-4bit",
    "unsloth/llama-3-70b-bnb-4bit",
    "unsloth/Phi-3-mini-4k-instruct",        # Phi-3 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",             # Gemma 2.2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    # model_name = "unsloth/llama-3-8b", # "unsloth/mistral-7b" for 16bit loading
    model_name = "unsloth/llama-3-8b-bnb-4bit", # "unsloth/mistral-7b" for 16bit loading
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Llama patching release 2024.6
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 8.9. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!
#
# We also add `embed_tokens` and `lm_head` to allow the model to learn out of distribution data.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 128, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",

                      "embed_tokens", "lm_head",], # Add for continual pretraining
    lora_alpha = 32,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = True,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Offloading input_embeddings to disk to save VRAM
# Unsloth: Offloading output_embeddings to disk to save VRAM
# Unsloth 2024.6 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Unsloth: Casting embed_tokens to float32
# Unsloth: Casting lm_head to float32

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Tiny Stories dataset from https://huggingface.co/datasets/roneneldan/TinyStories. We only sample the first 5000 rows to speed training up. We must add `EOS_TOKEN` or `tokenizer.eos_token` or else the model's generation will go on forever.
#
# If you want to use the `ChatML` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing).

# %%
from datasets import load_dataset
# dataset = load_dataset("roneneldan/TinyStories", split = "train[:2500]")

import os
import pandas as pd
from datasets import Dataset

my_dataset = []

for filename in os.listdir('data'):
    if filename.endswith('.md'):
        with open(f'data/{filename}', 'r') as file:
            content = file.read()
            my_dataset.append({
                "text": content
            })

print(my_dataset)


df = pd.DataFrame(my_dataset)
dataset = Dataset.from_pandas(df)


EOS_TOKEN = tokenizer.eos_token
def formatting_func(example):
    return example["text"] + EOS_TOKEN
# Out:
# [{'text': "# Nico van Lier\n\n## Basic Information\n\n- **Full Name:** Nicholas Wenzel van Lier\n- **Affectionate Nicknames:** Nico\n- **Relationship to Marjo:** Son\n- **Mother's Name:** Lea van Lier\n- **Birth Date and Time:** 08 September 2021, 14:00 SAST\n- **Birth Location:** Roodepoort, Johannesburg, Gauteng, South Africa\n- **Distinguishing Features:** Striking blue eyes and vibrant ginger hair\n\n## Personal Summary\n\nNicholas Wenzel van Lier, affectionately known as Nico, is the beloved son of Marjo and Lea van Lier. He was born into a\nworld of joy and anticipation, embodying the unique beauty that further unites his family. With his bright blue eyes and\nlively ginger hair, Nico represents both the physical and emotional bond shared within the van Lier family. His life,\nfrom the first giggle to adventurous steps, celebrates the boundless possibilities each day holds. The presence of Nico\nhas signified a realm of unlimited happiness, deepening familial bonds and imparting the profound essence of\nunconditional love.\n\n## Significant Life Events\n\n- **The Journey to Parenthood:** Marjo and Lea’s journey towards welcoming Nico into their lives was characterized by\n  intimate, candlelit evenings, emblematic of their hope, love, and the emotional and spiritual groundwork for the new\n  life they were ready to embrace. This period wasn't merely about the anticipation of becoming a family but a\n  celebration of their profound connection and readiness for the journey ahead.\n\n- **The Night of Conception:** Nico was conceived in January 2021, during a series of intimate nights that stand out as\n  a testament to Marjo and Lea's love and mutual desire to start a family. These moments, surrounded by candlelight,\n  were not merely by chance but a deep expression of the couple's readiness for parenthood.\n\n- **Sharing the Joy:** Lea shared the joyous news of Nico's impending arrival with Marjo in a unique and heartfelt\n  manner—a creatively prepared box filled with baby essentials, signaling the start of an incredible shared journey into\n  family life. This tender gesture went beyond announcement, celebrating the transition into a family filled with love,\n  anticipation, and the joy of awaiting Nico's arrival.\n\n- **Nico's Baptism:** A pivotal event in Nico's life, his baptism held on 30 January 2022 at Mosaïek Church in Fairland,\n  Roodepoort, signifies a significant familial and spiritual milestone, underpinning the family's faith and hope for his\n  future.\n\n- **Change in Godparents:** As of April 2024, Nico's godparents are Marein Overbeeke and Sally-Ann Overbeeke.\n  Previously, his godparents were Chris and Ilze Overbeeke. The change reflects the family's close relationship with\n  Marein and Sally-Ann, who reside in the UK, offering a closer familial connection than with Chris and Ilze, who live\n  in South Africa. This adjustment aims to foster a supportive and nurturing environment for Nico, bridging geographical\n  distances to maintain strong family bonds.\n\n## Looking Forward\n\nThe world is an expansive place of discovery for Nico, and Marjo and Lea are devoted to nurturing his growth, curiosity,\nand joy in the unfolding world around him. His evolving engagement with life reflects the beauty in its simplicity and\nmarks the transition from infantile comforts to embracing growth. This journey is a poignant reminder of the transient\nnature of childhood and symbolizes not only Nico’s physical and cognitive development but also the emotional depth and\njoy inherent in every stage.\n\nMarjo and Lea eagerly anticipate guiding Nico through life's complexities, instilling in him the values they cherish\ndeeply. Every day with Nico is a treasured chapter in the continuing story of their family—a story replete with love,\nlearning, and laughter, highlighting the profound familial connections and collective journey enriched by Nico's arrival\nand continued growth.\n"}, {'text': '# Stiaan Cornelius van Lier\ ...

# %% [markdown]
# Print out 5 stories from `Tiny Stories`

# %%
for row in dataset[:5]["text"]:
    print("=========================")
    print(row)
# Out:
# =========================
# # Stiaan Cornelius van Lier
#
# ## Basic Information
#
# - Brother of Marjo Wenzel van Lier
# - Born on August 2, 1988, in Middelburg, Mpumalanga, South Africa
# - Currently resides in Roodepoort, Gauteng, South Africa
# - Currently works as an IT Admin & ArtiCUT Product Specialist at ArtiCAD Ltd in South Africa
#
# ## Family Background
#
# - Parents:
#     - Father: Hille Dominicus van Lier (born August 4, 1962, in Orange Free State, South Africa)
#     - Mother: Soria van Lier (née van Dyk) (born October 14, 1965, in Parow, Bellville, Cape Province, South Africa)
# - Siblings:
#     - Brother: Marjo Wenzel van Lier (born January 10, 1987, in Pretoria, Gauteng, South Africa)
#     - Brother: Henri Jurie van Lier (born October 31, 1990, in Vanderbijlpark, Transvaal, South Africa)
# - Partner:
#     - Wife: Chane van Lier (née Bekker) (born February 25, 1993, in Kempton Park, Ekurhuleni, Gauteng, South Africa) (
#       married on September 21, 2018, in Randburg, Gauteng, South Africa)
# - Children: No children reported.
# - The family background has been shaped by the diverse origins and locations within South Africa.
#
# ## Pivotal Life Events
#
# - Born on August 2, 1988, in Middelburg, Mpumalanga, South Africa
# - Married Chane Bekker on September 21, 2018, in Randburg, Gauteng, South Africa
#
# ## Educational & Professional Journey
#
# - **Education**:
#     - Attended Hoërskool Birchleigh and Hoërskool Bellville
#     - Studied at Ekurhuleni West College
# - **Career Progression**:
#     - Currently works as an IT Admin & ArtiCUT Product Specialist at ArtiCAD Ltd in South Africa
#     - Previous roles include:
#         - Junior Engineer at AMS Advanced Machine Systems S.A.
#         - Franchisee, Owner, and Profit-sharing Partner at Mr.VIDEO
#         - General Manager at Wimpy Restaurant
#         - FOH Manager at Panarottis
#         - Franchise Consultant for Mr.VIDEO (PTY) Ltd
#
# ## Personal Life & Well-being
#
# - Married to Chane Bekker since September 21, 2018
# - Additional personal life details are not available in the verified data
#
# ## Health Information
#
# - Has faced anxiety, depression, and ADHD
# - Managed ADHD with Ritalin from a young age into late schooling
# - Overcame an anxiety episode and depression in August 2012
# - Hospital admission for depression on May 20, 2015
#
# ## Skills, Interests & Additional Information
#
# - **Professional Skills**: IT administration, product specialization, franchise management, general management
# - Specific interests or community involvement are not documented in the provided data
#
# ## Personal Values & Philosophy
#
# - Personal values and philosophy are not detailed in the verified information
#
# ## Challenges & Obstacles Overcome
#
# - Faced and managed anxiety, depression, and ADHD throughout life
#
# ## Hobbies & Passions
#
# - Hobbies, interests, or passions are not detailed in the verified information
#
# ## Philanthropic Work & Community Involvement
#
# - Philanthropic work and community involvement are not detailed in the verified information
#
# ## Future Outlook
#
# - Aims to continue advancing in his career while maintaining a balanced family life
#
# ## Impact & Legacy
#
# - Recognized as a dedicated professional and a supportive family member within his community
#
# ## Life Story Summary
#
# Stiaan Cornelius van Lier, born on August 2, 1988, in Middelburg, Mpumalanga, South Africa, is known for his familial
# ties and personal milestones, particularly his marriage to Chane Bekker. His professional journey includes various
# roles, highlighting his adaptability and expertise. While many personal details remain unconfirmed, his life is marked
# by significant events and a strong commitment to both personal and professional development. His legacy reflects
# resilience in overcoming mental health challenges and dedication to his career and family.
#
# =========================
# # Marjo Wenzel van Lier
#
# ## Basic Information
#
# - **Full Name:** Marjo Wenzel van Lier
# - **Date of Birth:** January 10, 1987
# - **Place of Birth:** Pretoria, Tshwane, Gauteng, South Africa
# - **Current Residence:** Veghel, North Brabant, Netherlands
# - **Profession:** Senior Application Engineer at BAS World (as of June 2022)
#
# ## Family Background
#
# - **Parents:**
#     - **Father:** Hille Dominicus van Lier (nickname: Hildo, born August 4, 1962, in Orange Free State, South Africa)
#     - **Mother:** Soria van Lier (née van Dyk, born October 14, 1965, in Parow, Bellville, Cape Province, South Africa)
# - **Siblings:**
#     - **Brother:** Stiaan Cornelius van Lier (born August 2, 1988, in Middelburg, Mpumalanga, South Africa)
#     - **Brother:** Henri Jurie van Lier (born October 31, 1990, in Vanderbijlpark, Gauteng, South Africa)
# - **Spouse:** Cornelia Adriana Janna Overbeeke (nickname: Lea, born July 28, 1988, in Pretoria, Gauteng, South Africa)
#     - **Met:** May 17, 2014, at the Jacaranda Day music festival held at SuperSport Park in Centurion, South Africa
#     - **Started Dating:** June 6, 2014
#     - **Engaged:** December 16, 2018, at Biru, a Chinese hotpot restaurant in Sandton, Johannesburg, South Africa
#     - **Married:** February 29, 2020, in Tarlton, Mogale, West Rand, Gauteng, South Africa
# - **Children:**
#     - **Son:** Nicholas (Nico) Wenzel van Lier (born September 8, 2021, in Roodepoort, Johannesburg, Gauteng, South
#       Africa)
#
# ## Pivotal Life Events
#
# - **Marriage:**
#     - Marjo married Cornelia Adriana Janna Overbeeke (Lea) on February 29, 2020, in Tarlton, Mogale, West Rand, Gauteng,
#       South Africa.
# - **Birth of Son:**
#     - Nicholas (Nico) Wenzel van Lier was born on September 8, 2021, in Roodepoort, Johannesburg, Gauteng, South Africa.
#
# ## Personal Life & Well-being
#
# - Marjo Wenzel van Lier is married to Cornelia Adriana Janna Overbeeke (Lea). Together, they have a son, Nico, and
#   currently reside in Veghel, Netherlands. Marjo maintains a strong bond with his family despite the geographical
#   distance from his birthplace.
#
# ## Professional Journey
#
# - **Current Role:**
#     - Senior Application Engineer at BAS World in Veghel, North Brabant, Netherlands (as of June 2022)
# - Marjo's career has been marked by his dedication and expertise in engineering, particularly in application
#   engineering, which has taken him from South Africa to the Netherlands.
#
# ## Life Story Summary
#
# Marjo Wenzel van Lier, born in Pretoria, South Africa, has built a life characterized by strong family ties and
# professional achievements. His marriage to Cornelia Adriana Janna Overbeeke (Lea) and the birth of their son, Nico, are
# significant milestones. Relocating to Veghel, Netherlands, Marjo continues to excel professionally while maintaining his
# familial connections across continents. His story reflects resilience, dedication, and the balance of personal and
# professional fulfillment.
#
# =========================
# # Henri Jurie van Lier
#
# ## Basic Information
#
# - Brother of Marjo Wenzel van Lier
# - Born on October 31, 1990, in Vanderbijlpark, Gauteng, South Africa
# - Currently resides in London, England, United Kingdom
# - Currently works as a Catalogue Manager and Information Security Officer at ArtiCAD Ltd in England, United Kingdom
#
# ## Family Background
#
# - Parents:
#     - Father: Hille Dominicus van Lier (born August 4, 1962, in Orange Free State, South Africa)
#     - Mother: Soria van Lier (née van Dyk) (born October 14, 1965, in Parow, Bellville, Cape Province, South Africa)
# - Siblings:
#     - Brother: Marjo Wenzel van Lier (born January 10, 1987, in Pretoria, Gauteng, South Africa)
#     - Brother: Stiaan Cornelius van Lier (born August 2, 1988, in Middelburg, Mpumalanga, South Africa)
# - Partner:
#     - Wife: Shannon Mary van Lier (née Scott) (born October 16, 1989) (married on July 31, 2016, in Alberton,
#       Ekurhuleni, Gauteng, South Africa)
# - Children:
#     - Son: Adrian Henri van Lier (born December 21, 2018, in Wigan, Lancashire, England, United Kingdom)
#     - Daughter: Taniqa Mary van Lier (born February 26, 2023, in Luton, Bedfordshire, England, United Kingdom)
#
# ## Pivotal Life Events
#
# - Married Shannon Mary Scott on July 31, 2016, in Alberton, Ekurhuleni, Gauteng, South Africa
# - Welcomed his first child, a son named Adrian Henri van Lier, on December 21, 2018, in Wigan, Lancashire, England,
#   United Kingdom, when Henri was 28 and Shannon was 29.
# - Welcomed his second child, a daughter named Taniqa Mary van Lier, on February 26, 2023, in Luton, Bedfordshire,
#   England, United Kingdom, when Henri was 32 and Shannon was 33.
#
# ## Personal Life & Well-being
#
# - Married to Shannon Mary van Lier (née Scott) and a father, living in London. Details on personal challenges or health
#   issues are not provided.
# - Enjoys a stable family life with his wife and two children.
#
# ## Health Information
#
# - No significant health conditions or chronic illnesses reported.
#
# ## Skills, Interests & Additional Information
#
# - **Professional Skills**: As a Catalogue Manager and Information Security Officer, he manages product catalogues and
#   oversees information security protocols within the company.
# - Specific interests or community involvement are not documented in the provided data.
#
# ## Future Outlook
#
# - Aims to continue advancing in his career while maintaining a balanced family life.
#
# ## Impact & Legacy
#
# - Recognized as a dedicated professional and a loving family man within his community.
#
# ## Life Story Summary
#
# Henri Jurie van Lier, born on October 31, 1990, in Vanderbijlpark, South Africa, has established himself as a committed
# family man. Married to Shannon Mary van Lier (née Scott, born October 16, 1989), with whom he shares two children,
# Henri's life is marked by his dedication to his family and his career. His professional expertise and personal
# commitment to his family define his legacy as a respected individual in both his personal and professional circles.

# %% [markdown]
# <a name="Train"></a>
# ### Continued Pretraining
# Now let's use Unsloth's `UnslothTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 20 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.
#
# Also set `embedding_learning_rate` to be a learning rate at least 2x or 10x smaller than `learning_rate` to make continual pretraining work!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
from unsloth import UnslothTrainer, UnslothTrainingArguments

trainer = UnslothTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 8,

    args = UnslothTrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 8,

        warmup_ratio = 0.1,
        num_train_epochs = 50,

        learning_rate = 5e-5,
        embedding_learning_rate = 5e-6,

        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.00,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=8):   0%|          | 0/8 [00:00<?, ? examples/s]

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 9.648 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 8 | Num Epochs = 50
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 8
# \        /    Total batch size = 16 | Total steps = 50
#  "-____-"     Number of trainable parameters = 1,386,217,472
# Unsloth: Setting lr = 5.00e-06 instead of 5.00e-05 for embed_tokens.
# Unsloth: Setting lr = 5.00e-06 instead of 5.00e-05 for lm_head.
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 14:43, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.886200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.885200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.860300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.789100</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.734700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.651900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.602600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.516000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.423500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.342200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.274700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.223900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.197800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.142800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.097000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.067900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.055800</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.036400</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.022400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.013500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.005600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.003500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.002300</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.002200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.001900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.001300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-21a4da9893ae> in <cell line: 3>()
#       1 #@title Show final memory and time stats
#       2 used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
# ----> 3 used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
#       4 used_percentage = round(used_memory         /max_memory*100, 3)
#       5 lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
#
# NameError: name 'start_gpu_memory' is not defined

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model!
#
# We first will try to see if the model follows the style and understands to write a story that is within the distribution of "Tiny Stories". Ie a story fit for a bed time story most likely.
#
# We select "Once upon a time, in a galaxy, far far away," since it normally is associated with Star Wars.

# %%
from transformers import TextIteratorStreamer
from threading import Thread
text_streamer = TextIteratorStreamer(tokenizer)
import textwrap
max_print_width = 100

inputs = tokenizer(
[
    # "Once upon a time, in a galaxy, far far away,"
    "Marjo Wenzel van Lier has two brothers, "
]*1, return_tensors = "pt").to("cuda")

generation_kwargs = dict(
    inputs,
    streamer = text_streamer,
    max_new_tokens = 256,
    use_cache = True,
)
thread = Thread(target = model.generate, kwargs = generation_kwargs)
thread.start()

length = 0
for j, new_text in enumerate(text_streamer):
    if j == 0:
        wrapped_text = textwrap.wrap(new_text, width = max_print_width)
        length = len(wrapped_text[-1])
        wrapped_text = "\n".join(wrapped_text)
        print(wrapped_text, end = "")
    else:
        length += len(new_text)
        if length >= max_print_width:
            length = 0
            print()
        print(new_text, end = "")
    pass
pass
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <|begin_of_text|>Marjo Wenzel van Lier has two brothers,2 sisters and 2 half-sisters. Marjo Wenzel
# van Lier is married to Marjo Wenzel van Lier. Marjo Wenzel van Lier's parents are Wessel Jurie van
# Lier and Soria van Dyk. Marjo Wenzel van Lier's siblings are Carl Johannes van Lier, Marinde Petronella
# van Lier, Chrissie Soria van Dyk, Cornelia Adriana Janna van Lier and Sally-Ann van Lier.
# Marjo Wenzel
# van Lier
# Marjo Wenzel van Lier (born December 8, 1967, in Parow, Bellville, Cape Province, South
# Africa) is a profoundly compassionate and versatile individual, with a life
# Marjo Wenzel van Lier (born
# December 8, 1967, in Parow, Bellville, Cape Province, South Africa) is a profoundly compassionate and
# versatile individual, with a life deeply rooted in familial ties and personal journeys. His story
# encapsulates a journey marked by resilience, diverse cultural experiences, and a relentless pursuit of growth.
# Let's explore Marjo's life story, a reflection of his resilience and the diverse cultural experiences he
# has navigated.
# Marjo

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Gemma 6 trillion tokens is 2.5x faster! [free Colab](https://colab.research.google.com/drive/10NbwlsRChbma1v55m8LAPYG15uQv6HLo?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>

# %%
# Save Model
model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
# Out:
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 5.7G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 32.64 out of 52.96 RAM for saving.
#  28%|██▊       | 9/32 [00:00<00:01, 17.60it/s]We will save to Disk and not RAM now.
# 100%|██████████| 32/32 [00:26<00:00,  1.20it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Done.

# %%
model.push_to_hub("marjovl", private=True, token = "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")
# Out:
# README.md:   0%|          | 0.00/574 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/5.54G [00:00<?, ?B/s]
# Saved model to https://huggingface.co/marjovl
